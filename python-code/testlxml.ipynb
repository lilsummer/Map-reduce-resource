# %%
import mwparserfromhell
import bz2file as bz2
myfile = []
with open("part-00026.xml") as f:
    for line in f:
        myfile.append(line)
        
filtered=['category:','help:','file:','talk:','template:','wikipedia:','image:','d:q','d:|w','project:',':en:','special:contributions','wp:tw','wikt:']

#uncompressedData = read('part-00026.xml')
import re

regex = re.compile(r':|#')

# %%
import itertools

a=[('a', 3), ('b',-3), ('c', -4), ('d', 9)]
aa =list(itertools.combinations(a,2))

aa[0][0]
# Out:
# ('a', 3)

# %%
import re
regex = re.compile(r':|#')
a = regex.search('#')
a == None
# Out:
# False

# %%
import re
re.search('^Category:', "Category: sss")

regex = re.compile(r':')
mylist = ['Category:sss', 'HIpster', "Talk:hhh", "::my", 'content:',':']
selected_files = filter(lambda i: not regex.search(i), mylist)
selected_files

regex.search('title') == None
not regex.search('title:')
# Out:
# False

# %%
myfile
# Out:
# ['  <page>\n',
#  '    <title>Yorkville, Ohio</title>\n',
#  '    <ns>0</ns>\n',
#  '    <id>150872</id>\n',
#  '    <revision>\n',
#  '      <id>629246985</id>\n',
#  '      <parentid>619320195</parentid>\n',
#  '      <timestamp>2014-10-12T01:11:25Z</timestamp>\n',
#  '      <contributor>\n',
#  '        <username>636Buster</username>\n',
#  '        <id>19376353</id>\n',
#  '      </contributor>\n',
#  '      <minor />\n',
#  '      <text xml:space="preserve">{{Infobox settlement\n',
#  '|official_name            = Yorkville, Ohio\n',
#  '|settlement_type          = [[Village (United States)|Village]]\n',
#  '|nickname                 = \n',
#  '|motto                    =\n',
#  '\n',
#  '&lt;!-- Images --&gt;\n',
#  '|image_skyline            = \n',
#  '|imagesize                = \n',
#  '|image_caption            = \n',
#  '|image_flag               = \n',
#  '|image_seal               =\n',
#  '\n',
#  '&lt;!-- Maps --&gt;\n',
# ...

# %%
from mrjob.job import MRJob
from mrjob.step import MRStep
from lxml import etree
import re
import heapq
import mwparserfromhell
import numpy as np
import math

#WORD_RE = re.compile(r"\w|\s")
#PAGE_RE = re.compile('<page>')
parselink = re.compile(r'\[\[(.*?)(\]\]|\|)')

def mapper_get_words(line):
    chunk = ''
    startStr = '<page>'
    endStr = '</page>'
    isPage = False
    if isPage:
        self.chunk += (' ' + line)
        if endStr in line:              
            isPage = False
            pagetag += 1
            doc = etree.fromstring(self.chunk)
            text = doc.find('revision/text').text
            title = doc.find('title').text
                #pid = doc.find('id/text').text
            if text:
                wikicode = mwparserfromhell.parse(text)
                links = wikicode.filter_wikilinks()
                links_new = set([link.encode('utf-8') for link in links])
                for link in links_new:
                    return (pagetag, link)
                
            chuck = ''

# %%
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
from io import StringIO, BytesIO

# %%
import pandas as pd
import bz2file as bz2

# %%
import zipfile

uncompressedData = bz2.BZ2File('part-00026.xml.bz2').read()
uncompressedData[:100]
# Out:
# '  <page>\n    <title>Yorkville, Ohio</title>\n    <ns>0</ns>\n    <id>150872</id>\n    <revision>\n      '

# %%
sample = uncompressedData[:100000000].split('\n')
WORD_RE = re.compile(r"[\w']+")
page_RE = re.compile('<page>')
page_RE_2 = re.compile('</page>')

# %%
for lin in sample:
    words = line.split(' ')
    for word in words:
        if word == '<page>':
            print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1fad9faad7fd> in <module>()
# ----> 1 for lin in sample:
#       2     words = line.split(' ')
#       3     for word in words:
#       4         if word == '<page>':
#       5             print
#
# NameError: name 'sample' is not defined

# %%
page_RE.findall(sample[0])
# Out:
# ['<page>']

# %%
#tree = ET.parse('testtext.xml')
#root = tree.getroot()
import bz2file as bz2
with open("part-00026.xml.bz2") as f:
    f.readline()
    print(f.readline())
import re
WORD_RE = re.compile(r"[\w']+")

page_RE_2 = re.compile('</page>')
with open("part-00026.xml.bz2") as f:
    xml = f.read()


print("".join(xml[:1000]))
# Out:
# ��	"
# u��D������::oc��3����s
# l�]���	�۠BP8--�T���I#����R��;s�����]Y�����[�1�/x����%$���﷼�z��ݙ��x�l����;��>����;�y����X���F^��Gu�U��r/j<�F��XcL�L�o��S�

# %%
import re
import mwparserfromhell
import numpy as np
import math

#WORD_RE = re.compile(r"\w|\s")
#PAGE_RE = re.compile('<page>')
parselink = re.compile(r'\[\[(.*?)(\]\]|\|)')

str1= '[[link1|link2|link3]]'
str1[1]+str1[2]+str1[3]
# Out:
# '[li'

# %%
match = parselink.search(str1)
match.group(0).split('[[')[1].split('|')[0].split(']]')[0]
# Out:
# 'link1'
